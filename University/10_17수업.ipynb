# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(2,input_dim=1))
model.add(Dense(1))

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import plot_model

visible = Input(shape=(10,)) # 10개 짜리 입력
hidden1 = Dense(10,activation='relu') (visible) # 10개 짜리 입력에 활성화 함수가 적용되어 출력됨
hidden2 = Dense(20,activation='relu') (hidden1)
hidden3 = Dense(30,activation='relu') (hidden2)
output = Dense(1,activation='sigmoid') (hidden3)
model = Model(inputs=[visible], outputs=[output])

model.summary()
# Sequential Model로도 구현할 수 있으나, Funtional Model로 구현했다.
# input's' -> 입력이 여러개
# output's' -> 출력이 여러개
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_20 (InputLayer)       [(None, 10)]              0
#
#  dense_46 (Dense)            (None, 10)                110
#
#  dense_47 (Dense)            (None, 20)                220
#
#  dense_48 (Dense)            (None, 30)                630
#
#  dense_49 (Dense)            (None, 1)                 31
#
# ...
# Total params: 991 (3.87 KB)
# Trainable params: 991 (3.87 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# '''
# Input
#
# 🔽 (visible, input+shape=(10,))
#
# Dense(10)
#
# 🔽 hidden1
#
# Dense(20)
#
# 🔽 hidden2
#
# Dense(10)
#
# 🔽 hidden3
#
# Dense(1,sigmoid)
#
# 🔽 output
#
# |
# '''

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,to_file='modell.jpg',show_shapes=True) ## not working
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Input

input_img = Input(shape=(28*28,))
features = Dense(512,activation='relu') (input_img)
output = Dense(10,activation='softmax') (features) # features의 512개의 출력을 10개의 출력으로 내보냄

model = keras.Model(inputs=[input_img], outputs=[output])
model.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_21 (InputLayer)       [(None, 784)]             0
#
#  dense_50 (Dense)            (None, 512)               401920
#
#  dense_51 (Dense)            (None, 10)                5130
#
# ...
# Total params: 407050 (1.55 MB)
# Trainable params: 407050 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.jpg',show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# from tensorflow.keras.models
# from tensorflow.keras.layers
# from tensorflow.keras.utils

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Dense
from tensorflow.keras.utils import plot_model

input1 = Input(shape = (28*28,))
output1 = Dense(1, activation='sigmoid') (input1)
output2 = Dense(10, activation='softmax') (input1)
model1 = keras.Model(inputs=[input1], outputs=[output1,output2])
model1.summary()
plot_model(model, to_file='model.jpg',show_shapes=True)
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_22 (InputLayer)       [(None, 784)]                0         []
#
#  dense_52 (Dense)            (None, 1)                    785       ['input_22[0][0]']
#
#  dense_53 (Dense)            (None, 10)                   7850      ['input_22[0][0]']
#
# ...
# Total params: 8635 (33.73 KB)
# Trainable params: 8635 (33.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Dense,Concatenate
from tensorflow.keras.utils import plot_model

input1 = Input(shape = (28*28,))
input2 = Input(shape = (28*28,))
input3 = Input(shape = (28*28,))

output1 = Concatenate() ([input1,input2])
output2 = Concatenate() ([input2,input3])

final_output = Concatenate() ([output1,output2])
model2 = keras.Model(inputs=[input1,input2,input3], outputs=[final_output])
model2.summary()
# Out:
# Model: "model_18"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_29 (InputLayer)       [(None, 784)]                0         []
#
#  input_30 (InputLayer)       [(None, 784)]                0         []
#
#  input_31 (InputLayer)       [(None, 784)]                0         []
#
#  concatenate_5 (Concatenate  (None, 1568)                 0         ['input_29[0][0]',
#  )                                                                   'input_30[0][0]']
#
#  concatenate_6 (Concatenate  (None, 1568)                 0         ['input_30[0][0]',
#  )                                                                   'input_31[0][0]']
#
#  concatenate_7 (Concatenate  (None, 3136)                 0         ['concatenate_5[0][0]',
#  )                                                                   'concatenate_6[0][0]']
#
# ...

# %% [markdown]
# ## colab 10_17 참고
