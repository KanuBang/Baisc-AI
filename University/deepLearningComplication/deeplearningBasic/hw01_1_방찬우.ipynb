# %% [markdown]
# 데이터명 : Boston Housing Price (보스턴 주택 가격 데이터)
#
# 데이터설명 : 보스턴 시의 주택 가격에 대한 데이터이다.
# 주택의 여러가진 요건들과 주택의 가격 정보가 포함되어 있다. 주택의 가격에 영향을 미치는 요소를 분석하고자 하는 목적으로 사용될 수 있다. 회귀분석 등의 분석에 활용될 수 있다.
#
# 보스턴 주택 데이터는 여러 개의 측정지표들 (예를 들어, 범죄율, 학생/교사 비율 등)을 포함한, 보스턴 인근의 주택 가격의 중앙값(median value)이다. 이 데이터 집합은 14개의 변수를 포함하고 있다.
#
# 필드의 이해 :
# 데이터의 이해를 돕기 위해 포함된 14개의 변수에 대하여 간략하게 설명한다.
# 위 14개의 필드는 입력 변수로 사용되고, 맨 아래의 Play 속성이 목표(종속) 변수로 사용된다.
#
#  [01]  CRIM	자치시(town) 별 1인당 범죄율
#
#  [02]  ZN	25,000 평방피트를 초과하는 거주지역의 비율
#
#  [03]  INDUS	비소매상업지역이 점유하고 있는 토지의 비율
#
#  [04]  CHAS	찰스강에 대한 더미변수(강의 경계에 위치한 경우는 1, 아니면 0)
#
#  [05]  NOX	10ppm 당 농축 일산화질소
#
#  [06]  RM	주택 1가구당 평균 방의 개수
#
#  [07]  AGE	1940년 이전에 건축된 소유주택의 비율
#
#  [08]  DIS	5개의 보스턴 직업센터까지의 접근성 지수
#
#  [09]  RAD	방사형 도로까지의 접근성 지수
#
#  [10]  TAX	10,000 달러 당 재산세율
#
#  [11]  PTRATIO	자치시(town)별 학생/교사 비율
#
#  [12]  B	1000(Bk-0.63)^2, 여기서 Bk는 자치시별 흑인의 비율을 말함.
#
#  [13]  LSTAT	모집단의 하위계층의 비율(%)
#
#  [14]  MEDV	본인 소유의 주택가격(중앙값) (단위: $1,000)

# %%
from tensorflow import keras
(train_data, train_label), (test_data, test_label) = keras.datasets.boston_housing.load_data()

# %%
train_data.shape
# Out:
# (404, 13)

# %%
train_label.shape
# Out:
# (404,)

# %%
print(train_data[0:5])
# Out:
# [[1.23247e+00 0.00000e+00 8.14000e+00 0.00000e+00 5.38000e-01 6.14200e+00
#   9.17000e+01 3.97690e+00 4.00000e+00 3.07000e+02 2.10000e+01 3.96900e+02
#   1.87200e+01]
#  [2.17700e-02 8.25000e+01 2.03000e+00 0.00000e+00 4.15000e-01 7.61000e+00
#   1.57000e+01 6.27000e+00 2.00000e+00 3.48000e+02 1.47000e+01 3.95380e+02
#   3.11000e+00]
#  [4.89822e+00 0.00000e+00 1.81000e+01 0.00000e+00 6.31000e-01 4.97000e+00
#   1.00000e+02 1.33250e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.75520e+02
#   3.26000e+00]
#  [3.96100e-02 0.00000e+00 5.19000e+00 0.00000e+00 5.15000e-01 6.03700e+00
#   3.45000e+01 5.98530e+00 5.00000e+00 2.24000e+02 2.02000e+01 3.96900e+02
#   8.01000e+00]
#  [3.69311e+00 0.00000e+00 1.81000e+01 0.00000e+00 7.13000e-01 6.37600e+00
#   8.84000e+01 2.56710e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.91430e+02
#   1.46500e+01]]

# %%
print(train_label[0:10])
# Out:
# [15.2 42.3 50.  21.1 17.7 18.5 11.3 15.6 15.6 14.4]

# %%
print(set(train_label))
# Out:
# {5.0, 6.3, 7.2, 8.8, 9.6, 10.9, 11.3, 12.1, 13.3, 14.4, 15.2, 15.6, 17.7, 18.5, 17.9, 19.9, 21.1, 15.7, 23.1, 24.1, 22.5, 24.0, 27.5, 22.9, 22.3, 30.8, 25.0, 32.9, 24.7, 34.7, 34.9, 30.1, 31.5, 32.0, 36.4, 39.8, 38.7, 42.3, 43.5, 41.7, 36.2, 46.0, 44.0, 48.5, 8.5, 50.0, 10.5, 48.8, 48.3, 45.4, 11.0, 11.5, 12.5, 13.5, 14.5, 14.0, 15.0, 16.6, 16.1, 16.5, 16.0, 16.4, 17.5, 17.1, 17.0, 17.4, 18.4, 18.9, 18.0, 18.1, 19.1, 19.5, 19.4, 19.6, 19.0, 20.4, 20.0, 20.6, 20.5, 20.1, 21.0, 21.4, 21.6, 21.9, 22.0, 22.6, 22.4, 22.1, 23.0, 23.9, 23.6, 23.4, 23.5, 24.4, 24.6, 24.5, 25.1, 26.6, 26.4, 26.5, 27.9, 27.1, 28.6, 28.0, 28.5, 29.4, 29.1, 29.9, 29.0, 30.5, 31.1, 31.6, 31.0, 32.2, 32.7, 33.4, 33.1, 8.4, 33.2, 33.3, 34.6, 33.8, 35.2, 10.4, 7.5, 36.5, 36.1, 11.9, 7.0, 37.0, 37.3, 37.9, 37.6, 37.2, 13.9, 13.4, 14.9, 41.3, 43.8, 44.8, 8.3, 8.7, 10.2, 10.8, 11.7, 11.8, 12.7, 12.3, 12.8, 13.2, 13.8, 14.3, 14.2, 14.8, 15.3, 16.7, 16.2, 16.3, 16.8, 17.8, 17.2, 17.3, 18.7, 18.3, 18.2, 18.8, 19.3, 19.7, 19.8, 19.2, 20.3, 20.2, 20.7, 20.8, 21.7, 21.2, 21.8, 22.2, 22.8, 22.7, 23.7, 23.3, 23.8, 23.2, 24.8, 24.3, 25.3, 25.2, 26.2, 28.7, 28.2, 29.8, 30.7, 30.3, 31.7, 12.6, 13.1, 13.6, 14.6, 14.1, 15.1}

# %% [markdown]
# # 문제:회귀
# # 입력:13
# # 출력:1

# %%
# 학습 모델 만들기
from tensorflow.keras import layers

model = keras.Sequential()

model.add(layers.Dense(6,activation='relu',input_shape=(13,)))
model.add(layers.Dense(1,activation='linear'))
model.summary()
# 주어진 데이터에 맞게 input_shape을 설정
# model = model.add ( layers.Dense( ... ) )
# ....

# 마지막 layer는 출력에 맞게 Dense(1, activation='...')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 6)                 84
#
#  dense_7 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 91 (364.00 Byte)
# Trainable params: 91 (364.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# loss 함수 정하기
# model.compile( ... )
model.compile(optimizer='rmsprop',loss='mse',metrics='mae')

# %%
# 학습하기
# model.fit( ... )
model.fit(train_data,train_label,epochs=5)
# Out:
# Epoch 1/5
# 13/13 [==============================] - 0s 10ms/step - loss: 39088.3828 - mae: 189.0851
# Epoch 2/5
# 13/13 [==============================] - 0s 6ms/step - loss: 27310.1406 - mae: 156.8707
# Epoch 3/5
# 13/13 [==============================] - 0s 6ms/step - loss: 19475.7773 - mae: 130.8590
# Epoch 4/5
# 13/13 [==============================] - 0s 6ms/step - loss: 13410.7539 - mae: 106.7326
# Epoch 5/5
# 13/13 [==============================] - 0s 6ms/step - loss: 8686.9297 - mae: 82.7764

# %%
# 손실이 무지하게 크므로 전처리가 필요하다
# 봤을 때 target이 좀 전처리가 필요해보인다.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
#target인 1차원 이므로 2차원으로 바꿔야
train_label = train_label.reshape((-1,1))
test_label = test_label.reshape((-1,1))
sc.fit(train_label)
train_label = sc.transform(train_label)
test_label = sc.transform(test_label)

# %%
model.fit(train_data,train_label,epochs=5)
# 아까 보다 확실히 손실이 줄었다. epochs를 늘려보자
# Out:
# Epoch 1/5
# 13/13 [==============================] - 1s 15ms/step - loss: 7894.4463 - mae: 80.4371
# Epoch 2/5
# 13/13 [==============================] - 0s 12ms/step - loss: 4303.0425 - mae: 55.7173
# Epoch 3/5
# 13/13 [==============================] - 0s 15ms/step - loss: 2222.7703 - mae: 36.8252
# Epoch 4/5
# 13/13 [==============================] - 0s 11ms/step - loss: 1233.9412 - mae: 28.4806
# Epoch 5/5
# 13/13 [==============================] - 0s 12ms/step - loss: 918.5530 - mae: 26.3641

# %%
model.fit(train_data,train_label,epochs=100)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 9ms/step - loss: 12.2931 - mae: 2.6776
# Epoch 2/100
# 13/13 [==============================] - 0s 11ms/step - loss: 10.2936 - mae: 2.4543
# Epoch 3/100
# 13/13 [==============================] - 0s 8ms/step - loss: 9.1995 - mae: 2.2921
# Epoch 4/100
# 13/13 [==============================] - 0s 9ms/step - loss: 8.5567 - mae: 2.2507
# Epoch 5/100
# 13/13 [==============================] - 0s 10ms/step - loss: 7.4679 - mae: 2.0375
# Epoch 6/100
# 13/13 [==============================] - 0s 9ms/step - loss: 7.0858 - mae: 2.0138
# Epoch 7/100
# 13/13 [==============================] - 0s 8ms/step - loss: 7.0818 - mae: 2.0769
# Epoch 8/100
# 13/13 [==============================] - 0s 8ms/step - loss: 5.4499 - mae: 1.7740
# Epoch 9/100
# 13/13 [==============================] - 0s 8ms/step - loss: 5.5881 - mae: 1.8756
# Epoch 10/100
# 13/13 [==============================] - 0s 7ms/step - loss: 5.9999 - mae: 1.9138
# Epoch 11/100
# 13/13 [==============================] - 0s 7ms/step - loss: 5.6996 - mae: 1.8340
# Epoch 12/100
# 13/13 [==============================] - 0s 7ms/step - loss: 5.1695 - mae: 1.7612
# Epoch 13/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.8999 - mae: 1.5291
# Epoch 14/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.9852 - mae: 1.5808
# Epoch 15/100
# 13/13 [==============================] - 0s 8ms/step - loss: 5.4575 - mae: 1.8625
# Epoch 16/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.0532 - mae: 1.3794
# Epoch 17/100
# 13/13 [==============================] - 0s 8ms/step - loss: 4.2964 - mae: 1.5892
# Epoch 18/100
# 13/13 [==============================] - 0s 8ms/step - loss: 4.6040 - mae: 1.6306
# Epoch 19/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.5039 - mae: 1.4740
# Epoch 20/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.8740 - mae: 1.5361
# Epoch 21/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.9011 - mae: 1.4962
# Epoch 22/100
# 13/13 [==============================] - 0s 11ms/step - loss: 2.4593 - mae: 1.2687
# Epoch 23/100
# 13/13 [==============================] - 0s 8ms/step - loss: 4.4772 - mae: 1.7208
# Epoch 24/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7300 - mae: 1.3202
# Epoch 25/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.8863 - mae: 1.5995
# Epoch 26/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.8879 - mae: 1.3700
# Epoch 27/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7420 - mae: 1.3346
# Epoch 28/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7116 - mae: 1.3333
# Epoch 29/100
# 13/13 [==============================] - 0s 9ms/step - loss: 3.2152 - mae: 1.4056
# Epoch 30/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.6039 - mae: 1.3100
# Epoch 31/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.2602 - mae: 1.4948
# Epoch 32/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.5622 - mae: 1.2999
# Epoch 33/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.5693 - mae: 1.2801
# Epoch 34/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.6208 - mae: 1.2663
# Epoch 35/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.1662 - mae: 1.4235
# Epoch 36/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3515 - mae: 1.2294
# Epoch 37/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.2400 - mae: 1.2172
# Epoch 38/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7457 - mae: 1.3399
# Epoch 39/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.6217 - mae: 1.2739
# Epoch 40/100
# 13/13 [==============================] - 0s 8ms/step - loss: 3.0390 - mae: 1.4189
# Epoch 41/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.8449 - mae: 1.4212
# Epoch 42/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3529 - mae: 1.1971
# Epoch 43/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7855 - mae: 1.3316
# Epoch 44/100
# 13/13 [==============================] - 0s 8ms/step - loss: 1.9863 - mae: 1.1302
# Epoch 45/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.6174 - mae: 1.2979
# Epoch 46/100
# 13/13 [==============================] - 0s 8ms/step - loss: 1.9370 - mae: 1.0778
# Epoch 47/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0856 - mae: 1.1085
# Epoch 48/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.4072 - mae: 1.2637
# Epoch 49/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7544 - mae: 1.3819
# Epoch 50/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.4741 - mae: 1.3293
# Epoch 51/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3521 - mae: 1.2259
# Epoch 52/100
# 13/13 [==============================] - 0s 9ms/step - loss: 1.4364 - mae: 0.9514
# Epoch 53/100
# 13/13 [==============================] - 0s 10ms/step - loss: 2.4681 - mae: 1.2477
# Epoch 54/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.1956 - mae: 1.1999
# Epoch 55/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.3313 - mae: 1.2041
# Epoch 56/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7822 - mae: 1.4107
# Epoch 57/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.2877 - mae: 1.2680
# Epoch 58/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.2472 - mae: 1.2329
# Epoch 59/100
# 13/13 [==============================] - 0s 8ms/step - loss: 1.9832 - mae: 1.1657
# Epoch 60/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0886 - mae: 1.1637
# Epoch 61/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.1157 - mae: 1.1939
# Epoch 62/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.3058 - mae: 1.2652
# Epoch 63/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0077 - mae: 1.1321
# Epoch 64/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.0817 - mae: 1.1777
# Epoch 65/100
# 13/13 [==============================] - 0s 8ms/step - loss: 1.3232 - mae: 0.9451
# Epoch 66/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.6868 - mae: 1.3348
# Epoch 67/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.5261 - mae: 1.3429
# Epoch 68/100
# 13/13 [==============================] - 0s 10ms/step - loss: 2.3296 - mae: 1.2130
# Epoch 69/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.9466 - mae: 0.7706
# Epoch 70/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.6673 - mae: 1.3343
# Epoch 71/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.2273 - mae: 1.2022
# Epoch 72/100
# 13/13 [==============================] - 0s 9ms/step - loss: 1.9765 - mae: 1.1385
# Epoch 73/100
# 13/13 [==============================] - 0s 9ms/step - loss: 1.6673 - mae: 1.0249
# Epoch 74/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.3310 - mae: 1.2288
# Epoch 75/100
# 13/13 [==============================] - 0s 11ms/step - loss: 2.1162 - mae: 1.2345
# Epoch 76/100
# 13/13 [==============================] - 0s 13ms/step - loss: 2.5016 - mae: 1.2795
# Epoch 77/100
# 13/13 [==============================] - 0s 12ms/step - loss: 2.1557 - mae: 1.1770
# Epoch 78/100
# 13/13 [==============================] - 0s 12ms/step - loss: 1.3954 - mae: 0.9425
# Epoch 79/100
# 13/13 [==============================] - 0s 11ms/step - loss: 2.8828 - mae: 1.3292
# Epoch 80/100
# 13/13 [==============================] - 0s 11ms/step - loss: 1.6732 - mae: 1.0091
# Epoch 81/100
# 13/13 [==============================] - 0s 11ms/step - loss: 1.9409 - mae: 1.1543
# Epoch 82/100
# 13/13 [==============================] - 0s 13ms/step - loss: 2.3484 - mae: 1.1938
# Epoch 83/100
# 13/13 [==============================] - 0s 17ms/step - loss: 1.6811 - mae: 1.0436
# Epoch 84/100
# 13/13 [==============================] - 0s 15ms/step - loss: 2.0870 - mae: 1.2333
# Epoch 85/100
# 13/13 [==============================] - 0s 15ms/step - loss: 1.9566 - mae: 1.1861
# Epoch 86/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.8054 - mae: 1.7048
