# %%
import tensorflow as tf

(x_train, y_train),(x_test,y_test) = tf.keras.datasets.fashion_mnist.load_data()
# (x_train, y_train),(x_test,y_test) = tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# x_train is a NumPy array containing the training images.
#
# y_train is a NumPy array containing the labels for the training images.
#
# x_test is a NumPy array containing the test images.
#
# y_test is a NumPy array containing the labels for the test images.
#
#
# # 최적화: 손실 함수 아래 페이지 중요 3장 ppt
# ![image.png](attachment:image.png)

# %%
x_train.shape

# %%
y_train.shape

# %%
y_train[:10]

# %%
set(y_train) # unique data(number)

# %%
### 입력(28,28)이미지 6만장
x_train = x_train.reshape((60000, 28,28,1)) / 255 # (28,28) -> (784), /255 하는 이유 -> 0과1사이로 변환
print(x_train.shape)
### 출력 숫자: {0,1,2, ...., 9}
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
print(y_train.shape)

# %% [markdown]
# # Dense layer 사용 -> 1차원 데이터만 처리
# # 출석 체크 못 했음.
# ![image.png](attachment:image.png)

# %%
from tensorflow import keras
from tensorflow.keras import layers
#stride, padding
model = keras.Sequential()
model.add(layers.Conv2D(512, (3*3), strides=(1,1), padding='same',activation='relu', input_shape=(28,28,1)))
model.add(layers.Conv2D(512, (3*3), strides=(1,1), padding='same',activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(512, (3*3), strides=(1,1), padding='same',activation='relu', input_shape=(28,28,1)))
model.add(layers.Conv2D(512, (3*3), strides=(1,1), padding='same',activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(512, (3*3), strides=(1,1), padding='same',activation='relu', input_shape=(28,28,1)))
model.add(layers.Conv2D(512, (3*3), strides=(1,1), padding='same',activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(512, (3*3), strides=(1,1), padding='same',activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.summary()

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.summary()

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy']
             )

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model.fit(x_train,y_train, epochs=5)
