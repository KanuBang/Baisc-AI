# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Subtract, Add, Dense, Conv2D, Input, Concatenate

input1 = Input( shape=(28,28,192) )
conv11   = Conv2D(64, (1,1), padding='same') (input1)
conv11_33 = Conv2D(96, (1,1), padding='same') (input1)
conv11_55 = Conv2D(16, (1,1), padding='same') (input1)
maxpooling = MaxPooling2D( (3,3), strides=1,
                          padding='same') (input1)
conv33 = Conv2D(128, (3,3), padding='same') (conv11_33)
conv55 = Conv2D(32, (5,5), padding='same') (conv11_55)
conv11_maxpooling = Conv2D(32, (1,1), padding='same') (maxpooling)

output = Concatenate() ([conv11, conv33, conv55, conv11_maxpooling])

model = keras.Model(inputs=[input1],
                    outputs=[output])
model.summary()
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.jpg', show_shapes=True)
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_30 (InputLayer)       [(None, 28, 28, 192)]        0         []
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 96)           18528     ['input_30[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 16)           3088      ['input_30[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 28, 28, 192)          0         ['input_30[0][0]']
#  D)
#
#  conv2d (Conv2D)             (None, 28, 28, 64)           12352     ['input_30[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)          110720    ['conv2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 32)           12832     ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 32)           6176      ['max_pooling2d[0][0]']
#
# ...
